# %% [markdown]
# ## Analysis

# %% [markdown]
# #### Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### Plot config

# %%
plt.title("Job Skills Analysis")
plt.xlabel("Skills")
plt.ylabel("Job Titles")
plt.grid(True) # Add a grid
